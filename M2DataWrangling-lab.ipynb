# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# pd.options.display.max_columns = None
pd.options.display.max_columns = None

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %%
df.head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1  Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                            EdLevel  \
# 0  United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1    New Zealand      No  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
#
#                                             EduOther               OrgSize  \
# ...

# %%
df.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11547    False
# 11548    False
# 11549    False
# 11550    False
# 11551    False
# Length: 11552, dtype: bool

# %%
df.duplicated().value_counts()
# Out:
# False    11398
# True       154
# dtype: int64

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
df.Respondent.duplicated().sum()
# Out:
# 154

# %%
# your code goes here
df.drop_duplicates(inplace=True)

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here

df.duplicated().value_counts()
# Out:
# False    11398
# dtype: int64

# %%
df.Respondent.duplicated().sum()
# Out:
# 0

# %%
df.Respondent.shape
# Out:
# (11398,)

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
df.isna().sum()
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
df['WorkLoc'].isnull().sum()
# Out:
# 32

# %%
df[df['WorkLoc'].isnull()]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 130           285                     I am a developer by profession      Yes
# 242           550                     I am a developer by profession      Yes
# 866          1847                     I am a developer by profession      Yes
# 1455         2826                     I am a developer by profession      Yes
# 1753         3536                     I am a developer by profession      Yes
# 2339         4768                     I am a developer by profession      Yes
# 2689         5562                     I am a developer by profession       No
# 2788         5769                     I am a developer by profession      Yes
# 3165         6613                     I am a developer by profession       No
# 3213         6721                     I am a developer by profession       No
# 3690         7799  I am not primarily a developer, but I write co...      Yes
# ...

# %%
len(df[df['WorkLoc'].isnull()])
# Out:
# 32

# %%
df['WorkLoc'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
df['EdLevel'].isna().sum()
# Out:
# 112

# %%
df['Country'].isna().sum()
# Out:
# 0

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time    10968
# Employed part-time      430
# Name: Employment, dtype: int64

# %%
df['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering          6953
# Information systems, information technology, or system administration     794
# Another engineering discipline (ex. civil, electrical, mechanical)        759
# Web development or web design                                             410
# A natural science (ex. biology, chemistry, physics)                       403
# Mathematics or statistics                                                 372
# A business discipline (ex. accounting, finance, marketing)                244
# A social science (ex. anthropology, psychology, political science)        210
# A humanities discipline (ex. literature, history, philosophy)             207
# Fine arts or performing arts (ex. graphic design, music, studio art)      161
# I never declared a major                                                  124
# A health science (ex. nursing, pharmacy, radiology)                        24
# Name: UndergradMajor, dtype: int64

# %%
df['ConvertedComp'].value_counts()
# Out:
# 2000000.0    138
# 1000000.0    105
# 100000.0      99
# 150000.0      92
# 120000.0      86
#             ...
# 79183.0        1
# 20475.0        1
# 288732.0       1
# 22056.0        1
# 19880.0        1
# Name: ConvertedComp, Length: 3515, dtype: int64

# %%
# your code goes here
df['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
df['WorkLoc'].mode()
# Out:
# 0    Office
# Name: WorkLoc, dtype: object

# %%
df['WorkLoc'].head()
# Out:
# 0                                              Home
# 1                                            Office
# 2                                              Home
# 3                                              Home
# 4    Other place, such as a coworking space or cafe
# Name: WorkLoc, dtype: object

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here

#df['WorkLoc'] =df['WorkLoc'].fillna(df['WorkLoc'].mode()) #, inplace=True)
#df['WorkLoc'].fillna(value=df['WorkLoc'].mode(), inplace=True)

df['WorkLoc'].fillna(value='Office', inplace=True)

# %%
df.shape
# Out:
# (11398, 85)

# %%
# your code goes here
df['WorkLoc'].value_counts()
# Out:
# Office                                            6838
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
df['WorkLoc'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %%
'Annual Compensation' in df.columns
# Out:
# False

# %%
df['CompFreq'].head()
# Out:
# 0     Yearly
# 1     Yearly
# 2     Yearly
# 3    Monthly
# 4     Yearly
# Name: CompFreq, dtype: object

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
df["CompTotal"].value_counts()
# Out:
# 70000.0      241
# 60000.0      239
# 50000.0      223
# 100000.0     218
# 80000.0      194
#             ...
# 163500.0       1
# 2530000.0      1
# 1.0            1
# 162929.0       1
# 74400.0        1
# Name: CompTotal, Length: 1509, dtype: int64

# %%
 df['CompTotal'].head()
# Out:
# 0     61000.0
# 1    138000.0
# 2     90000.0
# 3     29000.0
# 4     90000.0
# Name: CompTotal, dtype: float64

# %%
salary_with_nan = []

for i in df.index:
    
    if df['CompFreq'][i]  == 'Yearly':
         salary_with_nan.append(df.loc[df['CompFreq'] == 'Yearly']['CompTotal'][i])     # salary  yearly keep as it is

        
    if df['CompFreq'][i] == 'Monthly':
         salary_with_nan.append(df.loc[df['CompFreq'] == 'Monthly']['CompTotal'][i]*12) # salary paid monthly to yearly
            
    if df['CompFreq'][i] == 'Weekly' :
        salary_with_nan.append(df.loc[df['CompFreq']  == 'Weekly']['CompTotal'][i]*52)  # salary paid weekly to yearly

# print the first 100 data of salary_with_nan list 
print(salary_with_nan[:50])
# Out:
# [61000.0, 138000.0, 90000.0, 348000.0, 90000.0, 114000.0, 36000.0, 103000.0, 69000.0, 96000.0, 84000.0, 114000.0, 104000.0, 1144000.0, 1152000.0, 156000.0, 18000.0, 76800.0, 60000.0, 400000.0, 47300.0, 618000.0, 345000.0, 85000.0, 107000.0, 66000.0, 76800.0, 50000.0, 800000.0, 75000.0, 216000.0, 100000.0, 1250000.0, 30000.0, 550000.0, nan, 8400000.0, 480000.0, 108000.0, 132000.0, 1200000.0, 50000.0, 33000.0, 110000.0, 66750.0, 300000.0, 3525600.0, 155000.0, 300000.0, 100000.0]

# %%
print('length salary_with_nan = ',  len(salary_with_nan))
print('length of df = ' , len(df))
# Out:
# length salary_with_nan =  11192
# length of df =  11398

# %%
 # adding the above 'salary_with_nan' list to df as a column using df.insert(index, column_name, data)
# Insert the 'salary_with_nan' at index location of 2 with column name 'NormalizedAnnualCompensation' 

df.insert(2, 'NormalizedAnnualCompensation', salary_with_nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 # adding the above 'salary_with_nan' list to df as a column using df.insert(index, column_name, data)
#       2 # Insert the 'salary_with_nan' at index location of 2 with column name 'NormalizedAnnualCompensation'
# ----> 4 df.insert(2, 'NormalizedAnnualCompensation', salary_with_nan)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4821, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
# -> 4821 value = self._sanitize_column(value)
#    4822 self._mgr.insert(loc, column, value)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
# ...

# %% [markdown]
# ### ValueError: Length of values (11192) does not match length of index (11398) this is due to 'NaN' values

# %% [markdown]
# ### Check 'CompFreq' & 'CompTotal' columns for NaN' values

# %%
df[['CompFreq','CompTotal']].isna().sum()
# Out:
# CompFreq       0
# CompTotal    809
# dtype: int64

# %% [markdown]
# ### Relace 'NaN' values in 'CompFreq' column with the mode value

# %%
df['CompFreq'].mode()
# Out:
# 0    Yearly
# Name: CompFreq, dtype: object

# %%
# replace 'NaN' values with the mode 'Yearly'
df['CompFreq'].fillna(value='Yearly', inplace=True)

# %% [markdown]
# ### Relace 'NaN' values in 'CompTotal' column with the mean value

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#df= df_can.loc[['Japan'], years]
df['CompTotal'].plot(kind='box', figsize=(6, 4))
# Out:
# <Axes: >

# %%
df.describe()['CompTotal']
# Out:
# count    1.139800e+04
# mean     7.082829e+05
# std      9.356453e+06
# min      0.000000e+00
# 25%      2.800000e+04
# 50%      7.000000e+04
# 75%      1.110000e+05
# max      7.000000e+08
# Name: CompTotal, dtype: float64

# %%
# who gets the highest payment? 
df.loc[df['CompTotal'] == 700000000.0, 
       ['CompTotal', 'YearsCode','Employment', 'WorkWeekHrs', 'LanguageWorkedWith',
        'EdLevel',  'UndergradMajor','Country', 'Ethnicity']]
# Out:
#         CompTotal YearsCode          Employment  WorkWeekHrs  \
# 6249  700000000.0        11  Employed full-time         45.0
#
#                                      LanguageWorkedWith  \
# 6249  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                           EdLevel  \
# 6249  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                          UndergradMajor  Country  \
# 6249  Computer science, computer engineering, or sof...  Lebanon
#
#            Ethnicity
# 6249  Middle Eastern

# %%
# who gets the minimum  payment? 
df.loc[df['CompTotal'] == 0.0, 
       ['CompTotal', 'YearsCode','Employment', 'WorkWeekHrs', 'LanguageWorkedWith',
        'EdLevel',  'UndergradMajor','Country', 'Ethnicity']]
# Out:
#       CompTotal YearsCode          Employment  WorkWeekHrs  \
# 128         0.0        25  Employed full-time         50.0
# 134         0.0         9  Employed full-time         40.0
# 982         0.0        11  Employed full-time         40.0
# 1381        0.0        12  Employed full-time         50.0
# 2010        0.0        15  Employed full-time         40.0
# 5424        0.0         7  Employed full-time         40.0
# 5582        0.0        29  Employed full-time         48.0
# 6530        0.0        40  Employed full-time         40.0
# 7543        0.0        25  Employed full-time         45.0
#
#                                      LanguageWorkedWith  \
# 128               C#;HTML/CSS;JavaScript;SQL;TypeScript
# 134                        HTML/CSS;Java;JavaScript;SQL
# 982               HTML/CSS;Java;JavaScript;PHP;Ruby;SQL
# 1381                     HTML/CSS;JavaScript;Python;SQL
# 2010  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# ...

# %%
df.loc[df['CompTotal'] == 70000.0].head(2)
# Out:
#     Respondent                      MainBranch Hobbyist  \
# 51         114  I am a developer by profession       No
# 64         139  I am a developer by profession      Yes
#
#                 OpenSourcer  \
# 51  Less than once per year
# 64  Less than once per year
#
#                                            OpenSource          Employment  \
# 51  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 64  The quality of OSS and closed source software ...  Employed full-time
#
#           Country Student                                   EdLevel  \
# 51         Canada      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 64  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                        UndergradMajor  \
# 51  Computer science, computer engineering, or sof...
# 64  Computer science, computer engineering, or sof...
#
#                                              EduOther  \
# ...

# %%
# 70000.0 is the most frequente 
print(len(df[df['CompTotal'] == 70000.0]))
print(len(df[df['CompTotal'] == 75000.0]))
print(len(df[df['CompTotal'] == 76000.0]))
# Out:
# 241
# 134
# 21

# %%
print(df['CompTotal'].median())
print(round(df['CompTotal'].mean(), 0))
print(df['CompTotal'].mode())
# Out:
# 70000.0
# 708283.0
# 0    70000.0
# Name: CompTotal, dtype: float64

# %% [markdown]
# ### The mean value (708283.0) is exaggerated because of the maximum value (700000000.0) and other outliers
# ### 50% have mode/median value ( 70000.0) so it is reasonable to replace 'CompTotal' column missing values with median/mode

# %%
df['CompTotal'].mode()
# Out:
# 0    70000.0
# Name: CompTotal, dtype: float64

# %%
# replace 'NaN' values with the mode/median 
df['CompTotal'].fillna(value= 70000.0, inplace=True)

# %%
df[['CompFreq','CompTotal']].isna().sum()
# Out:
# CompFreq     0
# CompTotal    0
# dtype: int64

# %% [markdown]
# ## We can now use if statements  to loop through

# %%
salary_no_nan = []

for i in df.index:
    
    if df['CompFreq'][i]  == 'Yearly':
         salary_no_nan.append(df.loc[df['CompFreq'] == 'Yearly']['CompTotal'][i])     # salary  yearly keep as it is

        
    if df['CompFreq'][i] == 'Monthly':
         salary_no_nan.append(df.loc[df['CompFreq'] == 'Monthly']['CompTotal'][i]*12) # salary paid monthly to yearly
            
    if df['CompFreq'][i] == 'Weekly' :
        salary_no_nan.append(df.loc[df['CompFreq']  == 'Weekly']['CompTotal'][i]*52)  # salary paid weekly to yearly

# print the first 100 data of salary_no_nan list 
print(salary_no_nan[:50])
# Out:
# [61000.0, 138000.0, 90000.0, 348000.0, 90000.0, 114000.0, 36000.0, 103000.0, 69000.0, 96000.0, 84000.0, 114000.0, 104000.0, 1144000.0, 1152000.0, 156000.0, 18000.0, 76800.0, 60000.0, 400000.0, 47300.0, 618000.0, 345000.0, 85000.0, 107000.0, 66000.0, 76800.0, 50000.0, 800000.0, 75000.0, 216000.0, 100000.0, 1250000.0, 30000.0, 550000.0, 70000.0, 8400000.0, 480000.0, 108000.0, 132000.0, 1200000.0, 50000.0, 33000.0, 110000.0, 66750.0, 300000.0, 3525600.0, 155000.0, 300000.0, 100000.0]

# %% [markdown]
# ### After replacing 'NaN' values  'salary_no_nan' list & df have the same length (11398) of data

# %%
print('length salary_no_nan = ', len(salary_no_nan))
print('length of df = ' , len(df))
# Out:
# length salary_no_nan =  11398
# length of df =  11398

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here

# adding the above  list 'salary_no_nan' to df as column using df.insert(index, column_name, data)
# Insert the 'salary_no_nan' at index location 2 with column name 'NormalizedAnnualCompensation' 

df.insert(2, 'NormalizedAnnualCompensation', salary_no_nan)

df.head(2)
# Out:
#    Respondent                      MainBranch  NormalizedAnnualCompensation  \
# 0           4  I am a developer by profession                       61000.0
# 1           9  I am a developer by profession                      138000.0
#
#   Hobbyist                 OpenSourcer  \
# 0       No                       Never
# 1      Yes  Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                            EdLevel  \
# 0  United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1    New Zealand      No  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# ...

# %%
df['NormalizedAnnualCompensation'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Comapre 'NormalizedAnnualCompensation' with the actual values of 'CompTotal' & 'CompFreq' columns

# %%
df[['CompFreq','CompTotal','NormalizedAnnualCompensation']].head(14)
# Out:
#    CompFreq  CompTotal  NormalizedAnnualCompensation
# 0    Yearly    61000.0                       61000.0
# 1    Yearly   138000.0                      138000.0
# 2    Yearly    90000.0                       90000.0
# 3   Monthly    29000.0                      348000.0
# 4    Yearly    90000.0                       90000.0
# 5   Monthly     9500.0                      114000.0
# 6   Monthly     3000.0                       36000.0
# 7    Yearly   103000.0                      103000.0
# 8    Yearly    69000.0                       69000.0
# 9   Monthly     8000.0                       96000.0
# 10  Monthly     7000.0                       84000.0
# 11   Yearly   114000.0                      114000.0
# 12   Weekly     2000.0                      104000.0
# 13   Weekly    22000.0                     1144000.0

# %%
df['NormalizedAnnualCompensation'].median()
# Out:
# 103000.0
