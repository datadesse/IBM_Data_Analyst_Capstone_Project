# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# pd.options.display.max_columns = None
pd.options.display.max_columns = None

pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %%
df.head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1  Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                            EdLevel  \
# 0  United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1    New Zealand      No  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
#
#                                             EduOther               OrgSize  \
# ...

# %%
df['Age'].median()
# Out:
# 29.0

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here

df['ConvertedComp'].plot(kind='kde')
# Add x-axis label
plt.xlabel('Salary converted to annual USD')
# Out:
# Text(0.5, 0, 'Salary converted to annual USD')

# %%
plt.ticklabel_format(style='plain')
df['ConvertedComp'].plot(kind='kde', figsize=(12, 4))
# Add x-axis label
plt.xlabel('Salary converted to annual USD')
# Out:
# Text(0.5, 0, 'Salary converted to annual USD')

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
plt.ticklabel_format(style='plain')
df['ConvertedComp'].plot(kind='hist', figsize=(10, 4))
# Add x-axis label
plt.xlabel('Salary converted to annual USD')
# Out:
# Text(0.5, 0, 'Salary converted to annual USD')

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 57745.0

# %%
df.loc[df['Gender'] == 'Man'].head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1  Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                            EdLevel  \
# 0  United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1    New Zealand      No  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
#
#                                             EduOther               OrgSize  \
# ...

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
len(df.loc[df['Gender'] == 'Man'])
# Out:
# 10480

# %%
df['Gender'].value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %%
df.loc[df['Gender'] == 'Woman'].head(2)
# Out:
#     Respondent                      MainBranch Hobbyist OpenSourcer  \
# 30          71  I am a developer by profession      Yes       Never
# 32          75  I am a developer by profession      Yes       Never
#
#                                            OpenSource          Employment  \
# 30  The quality of OSS and closed source software ...  Employed full-time
# 32  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#         Country         Student                                   EdLevel  \
# 30  Philippines              No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 32        India  Yes, full-time  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                        UndergradMajor  \
# 30  Computer science, computer engineering, or sof...
# 32  Computer science, computer engineering, or sof...
#
#                                              EduOther  \
# 30  Received on-the-job training in software devel...
# ...

# %%
df.loc[df['Gender'] == 'Woman']['ConvertedComp']
# Out:
# 30        4128.00
# 32       17491.00
# 38       16008.00
# 45      229016.00
# 68      135000.00
#            ...
# 11310         NaN
# 11330    47628.00
# 11343   175000.00
# 11371   110000.00
# 11385    38760.00
# Name: ConvertedComp, Length: 731, dtype: float64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df.loc[df['Gender'] == 'Woman']['ConvertedComp'].median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df.describe()['Age']
# Out:
# count   11111.00
# mean       30.78
# std         7.39
# min        16.00
# 25%        25.00
# 50%        29.00
# 75%        35.00
# max        99.00
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
df['Age'].plot(kind='hist',  figsize=(10, 4))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here

df['ConvertedComp'].plot(kind='box', vert=False, figsize=(10, 4))
# Out:
# <Axes: >

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here

# first quartiles 25% Q1 and  third quartiles 75% Q3.
# IQR (Inter Quartile Range)

Q1 = 26868 
Q3 = 100000
IQR = Q3 - Q1
IQR
# Out:
# 73132

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here

lower_bounds = Q1 -(1.5*IQR)
upper_bounds= Q3 + (1.5*IQR)

print('Lower_bounds = ', lower_bounds)
print( 'Upper_bounds = ', upper_bounds)
# Out:
# Lower_bounds =  -82830.0
# Upper_bounds =  209698.0

# %% [markdown]
# #### Lower_bound is  -82830 and upper bound is 209698, so anything outside of these values is an outlier.

# %%
# No outliers less than  -82830 
len(df[df['ConvertedComp']<  -82830])
# Out:
# 0

# %%
len(df[df['ConvertedComp'] > 209698])
# Out:
# 879

# %%
outliers = (df['ConvertedComp']<  -82830) | (df['ConvertedComp'] > 209698)
df[outliers].head(2)
# Out:
#     Respondent                      MainBranch Hobbyist OpenSourcer  \
# 3           16  I am a developer by profession      Yes       Never
# 13          32  I am a developer by profession       No       Never
#
#                                            OpenSource          Employment  \
# 3   The quality of OSS and closed source software ...  Employed full-time
# 13  The quality of OSS and closed source software ...  Employed full-time
#
#            Country Student                                      EdLevel  \
# 3   United Kingdom      No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13   United States      No                             Associate degree
#
#                                        UndergradMajor  \
# 3                                                 NaN
# 13  Information systems, information technology, o...
#
#                                              EduOther               OrgSize  \
# ...

# %%
df[outliers]['ConvertedComp'].sort_values( ascending=True)
# Out:
# 1046     209892.00
# 6638     209892.00
# 427      209931.00
# 2451     210000.00
# 10531    210000.00
#            ...
# 3698    2000000.00
# 3714    2000000.00
# 6615    2000000.00
# 6686    2000000.00
# 2495    2000000.00
# Name: ConvertedComp, Length: 879, dtype: float64

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
len(outliers)
# Out:
# 11398

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
df_without_outliers = df[(df['ConvertedComp']>= -82830) & (df['ConvertedComp'] <= 209698)]

# %% [raw]
# df_without_outliers[['ConvertedComp', 'Employment', 'Country', 'EdLevel']]

# %%
df_without_outliers['ConvertedComp'].max(), df_without_outliers['ConvertedComp'].min()
# Out:
# (209356.0, 0.0)

# %%
df_without_outliers['ConvertedComp'].median()
# Out:
# 52704.0

# %%
df_without_outliers['ConvertedComp'].mean()
# Out:
# 59883.20838915799

# %% [markdown]
# ## Compare the data after removing outliers

# %%
#plt.ticklabel_format(style='plain')
plt.figure(figsize=(20,6))

plt.subplot(2,2,1)
plt.ticklabel_format(style='plain')
sns.boxplot(df['ConvertedComp'], orient= 'h').set(title='With Outliers')

plt.subplot(2,2,3)
sns.boxplot(df_without_outliers['ConvertedComp'], orient= 'h').set(title='WithOut Outliers')

plt.show()

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
df.select_dtypes(include='number').head()
# Out:
#    Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs   Age
# 0           4   61000.00       61000.00        80.00         NaN 22.00
# 1           9  138000.00       95179.00        32.00       12.00 23.00
# 2          13   90000.00       90000.00        40.00        5.00 28.00
# 3          16   29000.00      455352.00        40.00         NaN 26.00
# 4          17   90000.00       65277.00        45.00        5.00 29.00

# %%
df._get_numeric_data().head()
# Out:
#    Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs   Age
# 0           4   61000.00       61000.00        80.00         NaN 22.00
# 1           9  138000.00       95179.00        32.00       12.00 23.00
# 2          13   90000.00       90000.00        40.00        5.00 28.00
# 3          16   29000.00      455352.00        40.00         NaN 26.00
# 4          17   90000.00       65277.00        45.00        5.00 29.00

# %%
df._get_numeric_data().corr()['Age']
# Out:
# Respondent       0.00
# CompTotal        0.01
# ConvertedComp    0.11
# WorkWeekHrs      0.04
# CodeRevHrs      -0.02
# Age              1.00
# Name: Age, dtype: float64

# %%
# your code goes here
df.select_dtypes(include='number').corr()['Age']
# Out:
# Respondent       0.00
# CompTotal        0.01
# ConvertedComp    0.11
# WorkWeekHrs      0.04
# CodeRevHrs      -0.02
# Age              1.00
# Name: Age, dtype: float64

# %%
df.select_dtypes(include='number').corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent           1.00      -0.01           0.00        -0.02        0.00
# CompTotal           -0.01       1.00           0.00         0.00        0.01
# ConvertedComp        0.00       0.00           1.00         0.02       -0.03
# WorkWeekHrs         -0.02       0.00           0.02         1.00        0.03
# CodeRevHrs           0.00       0.01          -0.03         0.03        1.00
# Age                  0.00       0.01           0.11         0.04       -0.02
#
#                 Age
# Respondent     0.00
# CompTotal      0.01
# ConvertedComp  0.11
# WorkWeekHrs    0.04
# CodeRevHrs    -0.02
# Age            1.00

# %%
df['Age'].describe()
# Out:
# count   11111.00
# mean       30.78
# std         7.39
# min        16.00
# 25%        25.00
# 50%        29.00
# 75%        35.00
# max        99.00
# Name: Age, dtype: float64

# %%
Q1_age = 25
Q3_age = 35
IQR_age = Q3_age - Q1_age
IQR_age
# Out:
# 10

# %%
age_lower_bounds = Q1_age -(1.5*IQR_age)
age_upper_bounds= Q3_age + (1.5*IQR_age)

print('Lower_bounds = ', age_lower_bounds)
print( 'Upper_bounds = ', age_upper_bounds)
# Out:
# Lower_bounds =  10.0
# Upper_bounds =  50.0

# %%
len(df[df['Age']<  10])
# Out:
# 0

# %%
len(df[df['Age']<  25])
# Out:
# 2096
